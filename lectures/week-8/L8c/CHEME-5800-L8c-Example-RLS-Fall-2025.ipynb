# %% [markdown]
# # Example: Ridge Regression Solution
# In this example, we will develop the solution to the ridge regression problem using direct computation of the data matrix inverse, and the Singular Value Decomposition (SVD) of the data matrix $\hat{\mathbf{X}}$.
#
# > __Learning Objectives:__
# >
# > Three learning objectives go here
#
# Let's get started!
# ___

# %% [markdown]
# ## Summary
# One summary sentence goes here.
#
# > __Key Takeaways:__
# >
# > There are three key takeaways here
#
# One concluding sentence goes here.
# ___
